# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
#Read in the dataframe
df=pd.read_csv('Data.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 681456 entries, 0 to 681455
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0                               681456 non-null  int64
#  1   POLICY_CODE                 681456 non-null  int64
#  2   PRODUCT_CODE                659606 non-null  object
#  3   DOC                         681456 non-null  object
#  4   EXPIRY_DATE                 681456 non-null  object
#  5   PRODUCT_TYPE                681456 non-null  object
#  6   TERMINATION_EFFECTIVE_DATE  623016 non-null  object
#  7   TERM                        681456 non-null  int64
#  8   PREMIUM_AMOUNT              681395 non-null  float64
#  9   SA                          681456 non-null  float64
#  10  STATUS_NAME                 681456 non-null  object
#  11  PREMIUM_STATUS              681456 non-null  object
#  12  PREMIUM_FREQUENCY           681456 non-null  object
#  13  MODE_NAME                   681456 non-null  object
#  14  GENDER                      681456 non-null  object
#  15  MARITAL_STATUS              499195 non-null  object
#  16  EDUCATION                   301886 non-null  object
#  17  BIRTHDAY                    681456 non-null  object
#  18  INCOME                      499072 non-null  float64
#  19  SALES_CHANNEL               681456 non-null  object
#  20  AGENT_PERSISTENCY           681456 non-null  float64
#  21  CLAWBACK_COMMISSION         272104 non-null  float64
#  22  TERMINATION_REASON          292303 non-null  object
# dtypes: float64(5), int64(3), object(15)
# memory usage: 119.6+ MB

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
# Out:
# Imported AutoViz_Class version: 0.0.81. Call using:
#     from autoviz.AutoViz_Class import AutoViz_Class
#     AV = AutoViz_Class()
#     AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)
# Note: verbose=0 or 1 generates charts and displays them in your local Jupyter notebook.
#       verbose=2 saves plots in your local machine under AutoViz_Plots directory and does not display charts.

# %%
filename = 'Data.csv'

# %%
dft = AV.AutoViz(filename,depVar='STATUS_NAME', header=0, verbose=1, lowess=False, chart_format='svg', max_rows_analyzed=150000, max_cols_analyzed=35)
# Out:
# Shape of your Data Set: (681456, 23)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     Number of Numeric Columns =  5
#     Number of Integer-Categorical Columns =  2
#     Number of String-Categorical Columns =  5
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  3
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  6
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     22 Predictors classified...
#         This does not include the Target column(s)
#         7 variables removed since they were ID or low-information variables
#     List of variables removed: ['   ', 'PRODUCT_CODE', 'DOC', 'EXPIRY_DATE', 'TERMINATION_EFFECTIVE_DATE', 'BIRTHDAY', 'TERMINATION_REASON']
# Since Number of Rows in data 681456 exceeds maximum, randomly sampling 150000 rows for EDA...
#
# ################ Multi_Classification VISUALIZATION Started #####################
# Data Set Shape: 150000 rows, 16 cols
# Data Set columns info:
# * POLICY_CODE: 0 nulls, 150000 unique vals, most common: {5001185279: 1, 100314495: 1}
# * PRODUCT_TYPE: 0 nulls, 2 unique vals, most common: {'Risk': 89452, 'Investment': 60548}
# * TERM: 0 nulls, 72 unique vals, most common: {24: 14258, 7982: 14006}
# * PREMIUM_AMOUNT: 15 nulls, 21023 unique vals, most common: {50.0: 19479, 60.0: 8713}
# * SA: 0 nulls, 2448 unique vals, most common: {0.0: 60548, 4000.0: 23291}
# * PREMIUM_STATUS: 0 nulls, 4 unique vals, most common: {'Regular': 135067, 'ILP Premium Paid-Up': 10017}
# * PREMIUM_FREQUENCY: 0 nulls, 5 unique vals, most common: {'Monthly': 149377, 'Single': 295}
# * MODE_NAME: 0 nulls, 8 unique vals, most common: {'Electronic Cash Collection': 40022, 'GSO': 39190}
# * GENDER: 0 nulls, 3 unique vals, most common: {'F': 76211, 'M': 64392}
# * MARITAL_STATUS: 40091 nulls, 5 unique vals, most common: {'Single': 73169, 'Married': 33765}
# * EDUCATION: 83580 nulls, 2 unique vals, most common: {'Others': 58867, 'Unknown': 7553}
# * INCOME: 40107 nulls, 29855 unique vals, most common: {120000.0: 2232, 24000.0: 2083}
# * SALES_CHANNEL: 0 nulls, 2 unique vals, most common: {'Tied': 106164, 'Broker': 43836}
# * AGENT_PERSISTENCY: 0 nulls, 2027 unique vals, most common: {0.0: 53978, 100.0: 1806}
# * CLAWBACK_COMMISSION: 90325 nulls, 30484 unique vals, most common: {0.0: 9866, -761.5238: 190}
# * STATUS_NAME: 0 nulls, 4 unique vals, most common: {'Terminated': 64092, 'Inforce': 46212}
# --------------------------------------------------------------------
#    Columns to delete:
# '   []'
#    Boolean variables %s
# "   ['PRODUCT_TYPE', 'EDUCATION', 'SALES_CHANNEL']"
#    Categorical variables %s
# ("   ['PREMIUM_STATUS', 'PREMIUM_FREQUENCY', 'MODE_NAME', 'GENDER', "
#  "'MARITAL_STATUS', 'POLICY_CODE', 'TERM', 'PRODUCT_TYPE', 'EDUCATION', "
#  "'SALES_CHANNEL']")
#    Continuous variables %s
# ("   ['PREMIUM_AMOUNT', 'SA', 'INCOME', 'AGENT_PERSISTENCY', "
#  "'CLAWBACK_COMMISSION']")
#    Discrete string variables %s
# ("   ['PRODUCT_CODE', 'DOC', 'EXPIRY_DATE', 'TERMINATION_EFFECTIVE_DATE', "
#  "'BIRTHDAY', 'TERMINATION_REASON']")
#    Date and time variables %s
# '   []'
#    ID variables %s
# "   ['   ']"
#    Target variable %s
# '   STATUS_NAME'
# Total Number of Scatter Plots = 15
# Could not draw Distribution Plots
# Time to run AutoViz (in seconds) = 73.465
#
#  ###################### VISUALIZATION Completed ########################
